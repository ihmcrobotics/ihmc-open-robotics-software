# %%
import os
import requests
import json
from datetime import datetime
import cv2
import numpy as np
import re
import sys

sys.path.append(os.path.abspath('../'))
from llm_interface import LLMInterface
os.environ['TOGETHER_API_KEY'] = '54402480f90ac00b73b61e4051df95f483a9a12f5960097e8eaf6caaa5a7a895'

# %%
print(" Calling the LLM ")
llm                 = LLMInterface(config_file="../config.json")
config              = json.load(open("../config.json"))
prompt              = config.get("prompt")
print("Prompt: ", prompt)
# Out:
#  Calling the LLM
# Prompt:  You are an intelligent action planner. Given the robot's current context, determine how to update the parameters of a particular action.If no valid next behavior exists, return 'NO_ACTION'. Do not include any code. Here the action is 'GOTO (to the person behind the barrier). GOTO action takes a single parameter: 'target'. The target is the object to which the robot should go. The task is to 'Go to the person behind the barrier who has the charge'. Return quoted string with the action parameters.{behavior_to_execute : '', object_name : '', pov_reference_frame_name :'',spatial_relation :''}

# %% [markdown]
# Sequential Actions given prompt : simple_prompt, Only_action_prompt

# %%
llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['GOTO CHARGE'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['SCAN'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['SCAN'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['PICK UP CHARGE'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['GOTO DOOR'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)
# Out:
# LLM Input for reasoning: {'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': ''}
# LLM Response: "GOTO CHARGE"

# %% [markdown]
# behvior_goto.py given prompt: GOTO_action_prompt

# %%
llm_input          = "{'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2'], 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': '-'}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)
# Out:
# LLM Input for reasoning: {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2'], 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': '-'}
# LLM Response: "GOTO"

# %% [markdown]
# Testing Natural Languge to Behaviors given prompt: NL_to_action_prompt

# %%
llm_input          = "{'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2'], 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': 'GOTO Person2', 'failed_behaviors': '-'}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)
# Out:
# LLM Input for reasoning: {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2'], 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': 'GOTO Person2', 'failed_behaviors': '-'}
# LLM Response: SCAN, GOTO Person2, RECEIVE OBJECT, GOTO DoorPanel1, PLACE CHARGE ON DOOR, GOTO Barrier1

# %% [markdown]
# behvior_goto.py given prompt: GOTO_action_prompt

# %%
llm_input          = "{'scene_objects': [{'object_name': 'DoorPullHandle1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.83381, y=2.47637, z=1.332), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7247180744148702, w=0.6890455083783673)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.8803427428244424, y=2.476369999856418, z=1.3319999446665518), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7247180744430904, w=0.6890455083486862)}}, {'object_name': 'DoorPanel1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.58971, y=2.53624, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6778173805500101, w=0.735230303118909)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.6362427428293465, y=2.5362399998764125, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6778173805198985, w=0.7352303031466693)}}, {'object_name': 'Person1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=2.01548, y=-0.57308, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.7149034243911725, w=0.6992232074193299)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=2.0620127425746597, y=-0.5730800001584628, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.7149034243625358, w=0.6992232074486089)}}, {'object_name': 'Person2', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.97584, y=-1.22519, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.7086125448297859, w=0.7055978042127502)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=2.022372742521245, y=-1.2251900001552158, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.708612544800888, w=0.7055978042417717)}}, {'object_name': 'Charge1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.5354, y=-0.48509, z=1.00433), 'orientation': geometry_msgs.msg.Quaternion(x=-0.013289830868172666, y=0.0007537625159451319, z=0.99830690943685, w=-0.0566226704440008)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.5819327425818674, y=-0.48509000011913916, z=1.0043299446665517), 'orientation': geometry_msgs.msg.Quaternion(x=-0.013289830868141797, y=0.0007537625164894216, z=0.998306909439169, w=-0.05662267040311482)}}, {'object_name': 'Barrier1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.77185, y=0.0, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6844199937260306, w=0.7290879728729999)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.8183827426216013, y=-1.3850692352351093e-10, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6844199936961705, w=0.7290879729010306)}}, {'object_name': 'Barrier2', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.83069, y=-0.01199, z=0.79907), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7197546790538979, w=0.694228494070951)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.8772227426206192, y=-0.011990000143326547, z=0.7990699446665517), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7197546790823303, w=0.6942284940414732)}}], 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': '-'}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)
# Out:
# LLM Input for reasoning: {'scene_objects': [{'object_name': 'DoorPullHandle1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.83381, y=2.47637, z=1.332), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7247180744148702, w=0.6890455083783673)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.8803427428244424, y=2.476369999856418, z=1.3319999446665518), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7247180744430904, w=0.6890455083486862)}}, {'object_name': 'DoorPanel1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.58971, y=2.53624, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6778173805500101, w=0.735230303118909)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.6362427428293465, y=2.5362399998764125, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6778173805198985, w=0.7352303031466693)}}, {'object_name': 'Person1', 'pose_in_world': {'pose': geometry_msgs.ms
# ...
