# %%
import os
import requests
import json
from datetime import datetime
import cv2
import numpy as np
import re
import sys

sys.path.append(os.path.abspath('../'))
from llm_interface import LLMInterface
os.environ['TOGETHER_API_KEY'] = '54402480f90ac00b73b61e4051df95f483a9a12f5960097e8eaf6caaa5a7a895'

# %%
print(" Calling the LLM ")
llm                 = LLMInterface(config_file="config.json")
config              = json.load(open("config.json"))
prompt              = config.get("prompt")
print("Prompt: ", prompt)
# Out:
#  Calling the LLM
# Prompt:  You are an intelligent planner. Given the robot's current context, determine the next valid behavior from the list of 'available_behaviors'.The task is to '1. First always SCAN the enviroonment to populate the scene_objects. 2. Go to the person behind the barrier. 3. Receive the charge from the person. 4. Go to door 5. Place the charge on the door. 6. Go behind the barrier.'. From the avaiable behaviors give the sequnece of behaviors to execute based on the task.If no valid next behavior exists, return 'NO_ACTION'. Do not include any code.

# %% [markdown]
# Sequential Actions given prompt : simple_prompt, Only_action_prompt

# %%
llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['GOTO CHARGE'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['SCAN'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['SCAN'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['PICK UP CHARGE'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)


llm_input          = "{'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': ['GOTO DOOR'], 'failed_behaviors': ''}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)
# Out:
# LLM Input for reasoning: {'scene_objects': ['DoorLever1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1'], 'available_behaviors': ['GOTO CHARGE', 'SCAN', 'PICK UP CHARGE', 'GOTO DOOR', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': ''}
# LLM Response: "GOTO CHARGE"

# %% [markdown]
# behvior_goto.py given prompt: GOTO_action_prompt

# %%
llm_input          = "{'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2'], 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': '-'}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)
# Out:
# LLM Input for reasoning: {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2'], 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': '-'}
# LLM Response: "GOTO"

# %% [markdown]
# Testing Natural Languge to Behaviors given prompt: NL_to_action_prompt

# %%
llm_input          = "{ 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': '-'}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)
# Out:
# LLM Input for reasoning: { 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': '-'}
# LLM Response: To determine the next valid behavior, we need to consider the task and the current context. The task is to scan the environment, go to the person behind the barrier, receive the charge, go to the door, place the charge on the door, and finally go behind the barrier.
#
# Given that 'previously_executed' is empty and 'failed_behaviors' is '-', we can assume that this is the starting point, and no behaviors have been executed or failed yet.
#
# The first step in the task is to 'SCAN the environment to populate the scene_objects'. Therefore, the next valid behavior is 'SCAN'. This behavior is available in the list of 'available_behaviors' and is the earliest logical step in achieving the task.
#
# After 'SCAN', the sequence of behaviors based on the task would be:
# ...

# %% [markdown]
# behvior_goto.py given prompt: GOTO_action_prompt

# %%
llm_input          = "{'scene_objects': [{'object_name': 'DoorPullHandle1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.83381, y=2.47637, z=1.332), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7247180744148702, w=0.6890455083783673)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.8803427428244424, y=2.476369999856418, z=1.3319999446665518), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7247180744430904, w=0.6890455083486862)}}, {'object_name': 'DoorPanel1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.58971, y=2.53624, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6778173805500101, w=0.735230303118909)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.6362427428293465, y=2.5362399998764125, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6778173805198985, w=0.7352303031466693)}}, {'object_name': 'Person1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=2.01548, y=-0.57308, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.7149034243911725, w=0.6992232074193299)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=2.0620127425746597, y=-0.5730800001584628, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.7149034243625358, w=0.6992232074486089)}}, {'object_name': 'Person2', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.97584, y=-1.22519, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.7086125448297859, w=0.7055978042127502)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=2.022372742521245, y=-1.2251900001552158, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.708612544800888, w=0.7055978042417717)}}, {'object_name': 'Charge1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.5354, y=-0.48509, z=1.00433), 'orientation': geometry_msgs.msg.Quaternion(x=-0.013289830868172666, y=0.0007537625159451319, z=0.99830690943685, w=-0.0566226704440008)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.5819327425818674, y=-0.48509000011913916, z=1.0043299446665517), 'orientation': geometry_msgs.msg.Quaternion(x=-0.013289830868141797, y=0.0007537625164894216, z=0.998306909439169, w=-0.05662267040311482)}}, {'object_name': 'Barrier1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.77185, y=0.0, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6844199937260306, w=0.7290879728729999)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.8183827426216013, y=-1.3850692352351093e-10, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6844199936961705, w=0.7290879729010306)}}, {'object_name': 'Barrier2', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.83069, y=-0.01199, z=0.79907), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7197546790538979, w=0.694228494070951)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.8772227426206192, y=-0.011990000143326547, z=0.7990699446665517), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7197546790823303, w=0.6942284940414732)}}], 'available_behaviors': ['GOTO', 'SCAN', 'RECEIVE OBJECT', 'PLACE CHARGE ON DOOR'], 'previously_executed': '', 'failed_behaviors': '-'}"

print("LLM Input for reasoning:", llm_input)

# Query LLM for next action
response        = llm.call_model(llm_input)
print("LLM Response:", response)
# Out:
# LLM Input for reasoning: {'scene_objects': [{'object_name': 'DoorPullHandle1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.83381, y=2.47637, z=1.332), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7247180744148702, w=0.6890455083783673)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.8803427428244424, y=2.476369999856418, z=1.3319999446665518), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=-0.7247180744430904, w=0.6890455083486862)}}, {'object_name': 'DoorPanel1', 'pose_in_world': {'pose': geometry_msgs.msg.Point(x=1.58971, y=2.53624, z=0.0), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6778173805500101, w=0.735230303118909)}, 'pose_wrt_robot': {'pose': geometry_msgs.msg.Point(x=1.6362427428293465, y=2.5362399998764125, z=-5.533344825392472e-08), 'orientation': geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.6778173805198985, w=0.7352303031466693)}}, {'object_name': 'Person1', 'pose_in_world': {'pose': geometry_msgs.ms
# ...

# %% [markdown]
# # Config_goto.json
# # Task : Go behind the person (perspective wall) to the right of the barrier (perspective Door)
# # Input to llm:
# llm_input = {
#             # "task": current_task,
#             "scene_objects_names": scene_objects_names,
#         }
#
# Eg: {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1']}
#
# # Expected output:
# target_object : Person
# spatial_relation : BEHIND
# pov_object : Wall1
#
# #If multiple scene objects have same target_object, then we need to use the object identifier, which will use the spatial information provided to identify the target object.
# #We assume pov_object is unique. In a more natural interaction that can be indeitifed through gestures or staring direction of the person giving commands.

# %% [markdown]
# # Config_goto.json
# # Task : Go behind the person (perspective wall) to the right of the barrier (perspective Door)
# # Role
# You serve as an AI decision module for robots operating in dynamic, partially observable environments. Your primary responsibility is to generate the correct parameters for a "go to" action based on natural language instructions.
# # Naming Convention
# Each object is uniquely identified by combining its base name with an ordinal suffix (e.g., "Person1", "Charge3").
# Output Format
# When given a natural language instruction, extract and present the following information in this order, each on a separate line:
#     The base name of the object to go to (e.g., "Cup")
#     The spatially related object with its full ordinal identifier (e.g., "Wall1"), or "-" if not specified
#     The spatial relation in uppercase (choose from "BEHIND", "FRONT", "RIGHT", "LEFT", or "DEFAULT" if not specified)
# # Special Instructions
# Carefully determine whether spatial relations are used to identify a specific object instance or to define the navigation action:
# For instructions such as "Go to the person behind the wall," the phrase "behind the wall" is used to identify the person. Only extract "go to the person" for the action parameters.
# # Output:
# Person
# -
# DEFAULT
# For instructions like "Go in front of the person (from the perspective of the couch)," the spatial relation directly defines the navigation action, so "in front of the person" should be included.
# # Output:
# Person
# Couch1
# FRONT
# In more complex cases such as "Go behind the person (perspective of couch) behind the wall," the first spatial relation ("go behind the person (perspective of couch)") defines the action, while the second ("behind the wall") helps identify the correct object instance. Only extract the part relevant to the action.
# # Output:
# Person
# Couch1
# BEHIND
# Restrictions
# Do not include any explanations, reasoning, or code in your response.
# Your output must consist of the three specified lines, each on a separate line, formatted as described above.

# %% [markdown]
# Here are some examples of how to respond in a standard interaction.
# Example 1:
# 'task_description': 'Go to the person behind the wall', the phrase "behind the wall" is used to identify the person.
# {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatial_relation' : 'DEFAULT',
# 'pov_object' : 'Wall1'}
#
# Example 2:
# 'task_description': 'Go in front of the person (from the perspective of the couch)', the spatial relation directly defines the navigation action, so "in front of the person" should be included. {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1', 'Couch1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatial_relation' : 'FRONT',
# 'pov_object' : 'Couch1'}
#
# Example 3: complex case
# 'task_description': 'Go behind the person (perspective of couch) behind the wall', the first spatial relation ("go behind the person (perspective of couch)") defines the action, while the second ("behind the wall") helps identify the correct object instance. {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1', 'Couch1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatial_relation' : 'BEHIND',
# 'pov_object' : 'Couch1'}

# %% [markdown]
# When given a natural language instruction in 'task_description', give a output json with {
# 'target_object' : ' The base name of the object to go to (e.g., "Cup")',
# 'spatial_relation' : 'The spatial relation in uppercase (choose from ['BEHIND', 'FRONT', 'RIGHT', 'LEFT', 'DEFAULT' if not specified])',
# 'pov_object' : 'The spatially related object with its full ordinal identifier (e.g., Wall1), or '-' if not specified from 'scene_objects''}.
# Do not include any explanations, reasoning, or code in your response.

# %% [markdown]
# # Config_obj_identifier.json
# # Task : Go behind the person (perspective wall) to the right of the barrier (perspective Door)
# # Input to llm:
# llm_input = {
#             # "task": current_task,
#             "scene_objects_names": scene_objects_names,
#         }
#
# Eg: {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1']}
#
#
# # Expected output:
# Person
# Barrier1
# RIGHT
# Wall1
#
# base_name = Person
# spatially_related_object = Barrier1
# spatial_relation = RIGHT
# pov_object = DoorPanel1
#
# object_name -> target_object : Person
# spatial_relation : BEHIND
# pov_reference_frame_name -> pov_object : Wall1
#
# # Use select_target_object to identify the below
# 1.
# 2.
# 3.

# %% [markdown]
# # Config_obj_identifier.json
# # Role
# You serve as an AI decision module for robots operating in dynamic, partially observable environments. Your primary responsibility is to resolve referential ambiguities during object interactions.
# Naming Convention
# All objects are uniquely identified by combining their base name with an ordinal suffix (e.g., "Person1", "Charge3").
# # Output
# When given a natural language instruction, extract and present the following information in this order, each on a separate line:
#     Base name of the target object (e.g., "Cup")
#     Spatially related object with its full ordinal identifier (e.g., "Wall1"), or "-" if not specified
#     Spatial relation in uppercase (choose from "BEHIND", "FRONT", "RIGHT", "LEFT", or "DEFAULT" if not specified)
#     Perspective object with its full ordinal identifier (e.g., "Couch1"), or "-" if not specified
# # Special Instructions
# Carefully distinguish whether spatial relations are used to identify a specific object instance or to define the navigation action:
# For instructions such as "Go in front of the person (from the perspective of the couch)," the spatial relation describes the action, not the object to select. In this case, only extract the target object, and use "-" and "DEFAULT" for the other fields.
# # Output:
# Person
# -
# DEFAULT
# -
# In more complex cases, such as "Go to the right of the person (perspective of couch) behind the wall," the first spatial relation ("to the right of (perspective of couch)") defines the action, while the second ("behind the wall") identifies the correct object instance. Only extract the information relevant to the object instance.
# # Output:
# Person
# Wall1
# BEHIND
# Couch1
# As a general rule, if a spatial relation appears before the name of the object to identify, it (along with its perspective) pertains to the action and should be ignored when extracting object instance information.
# # Restrictions
# Do not include any explanations, reasoning, or code in your response.
# Your output must consist of the four specified lines, each on a separate line, formatted as described above.

# %% [markdown]
# Here are some examples of how to respond in a standard interaction.
# Example 1:
# 'task_description': 'Go to the person behind the wall', the phrase "behind the wall" is used to identify the person.
# {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatially_related_object' : '-',
# 'spatial_relation' : 'DEFAULT',
# 'pov_object' : 'Wall1'}
#
# Example 2:
# 'task_description': 'Go in front of the person (from the perspective of the couch)', the spatial relation directly defines the navigation action, so "in front of the person" should be included. {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1', 'Couch1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatially_related_object' : '-',
# 'spatial_relation' : 'FRONT',
# 'pov_object' : 'Couch1'}
#
# Example 3: complex case
# 'task_description': 'Go behind the person (perspective of couch) to the left of the wall (perspective barrier)', the first spatial relation ("go behind the person (perspective of couch)") defines the action, while the second ("left of the wall") helps identify the correct object instance. {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1', 'Couch1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatially_related_object' : 'Wall1',
# 'spatial_relation' : 'LEFT',
# 'pov_object' : 'Barrier1'}
#
#
# goto_person_param : go to the person to the behind the barrier.
#  {
# 'target_object' : 'Person',
# 'spatial_relation_goto' : 'DEFAULT',
# 'pov_object_goto' : '-',
# 'spatially_related_object_obj' : 'Barrier1',
# 'spatial_relation_obj' : 'BEHIND',
# }
# goto_door_param : go infront of the door.
# {
# 'target_object' : 'Doorpanel1',
# 'spatial_relation_goto' : 'FRONT',
# 'pov_object_goto' : '-',
# 'spatially_related_object_obj' : '-',(only one door)
# 'spatial_relation_obj' : '-',
# }
# goto_barrier_param : go behind the barrier
# {
# 'target_object' : 'Barrier1',
# 'spatial_relation_goto' : 'BEHIND',
# 'pov_object_goto' : '-',
# 'spatially_related_object_obj' : '-',(only one door)
# 'spatial_relation_obj' : '-',
# }
#
# When given a natural language instruction in 'task_description', give a output json with {
# 'target_object' : 'The base name of the object to go to (e.g., "Cup")' if multiple instances of object is present else object with its full ordinal identifier (e.g., Wall1) from 'scene_objects',
# 'spatial_relation_goto' : 'The spatial relation realated to target_object in uppercase (choose from ['BEHIND', 'FRONT', 'RIGHT', 'LEFT', 'DEFAULT' if not specified])',
# 'pov_object_goto' : '-',
# 'spatially_related_object' : 'The spatially related object with its full ordinal identifier (e.g., Wall1), or '-' if not specified from 'scene_objects'',
# 'spatial_relation_obj' : 'The spatial relation in uppercase (choose from ['BEHIND', 'FRONT', 'RIGHT', 'LEFT', 'DEFAULT' if not specified])'
# }
# Do not include any explanations, reasoning, or code in your response.
#
#
# Here are some examples of how to respond in a standard interaction.
# Example 1:
# 'task_description': 'GoTo (to the person behind the couch)', the phrase "behind the wall" is used to identify the person.
# {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1', 'Couch1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatial_relation_goto' : 'DEFAULT',
# 'pov_object_goto' : '-',
# 'spatially_related_object'  : 'Couch1',
# 'spatial_relation_obj' : 'BEHIND'}
#
# Example 2:
# 'task_description': 'GoTo (in front of the person) ', the spatial relation directly defines the navigation action, so "in front of the person" should be included. {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1', 'Couch1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatial_relation_goto' : 'FRONT',
# 'pov_object_goto' : '-',
# 'spatially_related_object'  : '-',
# 'spatial_relation_obj' : '-'}
#
# Example 3: complex case
# 'task_description': 'GoTo (behind the person to the left of the couch)', the first spatial relation ("go behind the person ") defines the action, while the second ("left of the wall") helps identify the correct object instance. {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1', 'Couch1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatial_relation_goto' : 'BEHIND',
# 'pov_object_goto' : '-',
# 'spatially_related_object'  : 'Couch1',
# 'spatial_relation_obj' : 'LEFT'}
#
# Example 4:
# 'task_description': 'GoTo (to the person right of the couch)', the phrase "behind the wall" is used to identify the person.
# {'scene_objects': ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2', 'Wall1', 'Couch1']}.
# Output: {
# 'target_object' : 'Person',
# 'spatial_relation_goto' : 'DEFAULT',
# 'pov_object_goto' : '-',
# 'spatially_related_object'  : 'Couch1',
# 'spatial_relation_obj' : 'RIGHT'}

# %% [markdown]
# When given a natural language instruction in 'task_description', give a output json with {
# 'target_object' : ' The base name of the object to go to (e.g., "Cup")',
# 'spatially_related_object' : 'The spatially related object with its full ordinal identifier (e.g., Wall1), or '-' if not specified from 'scene_objects''
# 'spatial_relation' : 'The spatial relation in uppercase (choose from ['BEHIND', 'FRONT', 'RIGHT', 'LEFT', 'DEFAULT' if not specified])',
# 'pov_object' : 'Perspective object with its full ordinal identifier (e.g., Couch1), or '-' if not specified from 'scene_objects''}
# Do not include any explanations, reasoning, or code in your response.

# %%
import json

response = """{
'target_object' : 'Person',
'spatially_related_object' : 'Barrier1',
'spatial_relation' : 'BEHIND',
'pov_object' : '-'
}"""

# Replace single quotes with double quotes and remove any trailing commas or leading/trailing whitespace
clean_response = response.replace("'", '"')

# Convert string to dictionary
data = json.loads(clean_response)

# Extract variables
target_object = data['target_object']
spatially_related_object = data['spatially_related_object']
spatial_relation = data['spatial_relation']
pov_object = data['pov_object']

print(target_object)                # Person
print(spatially_related_object)     # Barrier1
print(spatial_relation)             # BEHIND
print(pov_object)                   # -

#Go behind the person (perspective wall) to the right of the barrier (perspective Door)
selected_object = select_target_object(
                base_name=lines[0],
                spatially_related_object='Barrier1',
                spatial_relation='RIGHT',
                scene_object_names=scene_objects_names,
                scene_object_positions=scene_objects_positions,
                robot_pose=robot_position,
                spatial_context_object='DoorPanel1')
# Out:
# Person
# Barrier1
# BEHIND
# -

# %%
goto_person_param = ("Person1", AI2RNavigationMessage.DEFAULT, "")

# %%
base_name = "Person"
candidates = [
        (name, pose) for name, pose in zip(scene_object_names, scene_object_positions)
        if name.startswith(base_name) and name[len(base_name):].isdigit()
    ]
print("candidates:", candidates)
if not candidates:
    print(f"No {base_name} objects found")
# Out:
# candidates: [('Person1', (2.01548, -0.57308, 0.0)), ('Person2', (1.97584, -1.22519, 0.0))]

# %%
scene_object_names = ['DoorPullHandle1', 'DoorPanel1', 'Person1', 'Person2', 'Charge1', 'Barrier1', 'Barrier2']
scene_object_positions = [
    (1.83381, 2.47637, 1.332),
    (1.58971, 2.53624, 0.0),
    (2.01548, -0.57308, 0.0),
    (1.97584, -1.22519, 0.0),
    (1.5354, -0.48509, 1.00433),
    (1.77185, 0.0, 0.0),
    (1.83069, -0.01199, 0.79907)
]

# %%
candidates = [('Person1', geometry_msgs.msg.Point(x=2.01548, y=0.39937999999999996, z=0.0)), ('Person2', geometry_msgs.msg.Point(x=1.97584, y=-0.25273, z=0.0))]

# %%
def point_to_numpy(point: Point) -> np.ndarray:
    """Convert geometry_msgs/Point to numpy array"""
    return np.array([point.x, point.y, point.z])


min(candidates, key=lambda x: np.linalg.norm(point_to_numpy(x[1]) - point_to_numpy(ref_pose)))[0]

# %%
target_object = 'Person1'
#check if the target object is in the scene
if target_object not in scene_object_names:
    print(f"Target object {target_object} not found in the scene.")

# %%
import re
response = """
To achieve the task described, the sequence of behaviors should follow the steps outlined in the task description, considering the available behaviors and the current state of the scene. Given that the scene_objects are not populated and the previously executed behavior is 'GOTO', the next logical step is to scan the environment to understand the layout and the objects present. 

behavior_list = [
    SCAN (the environment to populate scene_objects),
    GOTO (to the person behind the barrier),
    RECEIVE OBJECT (the charge from the person),
    GOTO (in front of the door),
    PLACE CHARGE ON DOOR,
    GOTO (behind the barrier)
]"""

# %%
match = re.search(r'behavior_list\s*=\s*\[(.*?)\]', response, re.DOTALL)
if match:
    list_block = match.group(1)

    # Extract each behavior entry including content inside parentheses
    behaviors = re.findall(r'([^\n,]+(?:\([^\)]*\))?)', list_block)
    print("Extracted Behaviors:", behaviors)

    # Step 3: Clean up whitespace
    llm_plan = [b.strip().rstrip(',') for b in behaviors]

    print('llm_plan : ', llm_plan)
    # Create list of [action, full_step]
    plan_queue = [[re.match(r'^([A-Z ]+)', step).group(1).strip(), step] for step in llm_plan]
    print("Plan Queue:", plan_queue)
else:
    print("No behavior_list found.")
# Out:
# Extracted Behaviors: ['    SCAN (the environment to populate scene_objects)', '    GOTO (to the person behind the barrier)', '    RECEIVE OBJECT (the charge from the person)', '    GOTO (in front of the door)', '    PLACE CHARGE ON DOOR', '    GOTO (behind the barrier)']
# llm_plan :  ['SCAN (the environment to populate scene_objects)', 'GOTO (to the person behind the barrier)', 'RECEIVE OBJECT (the charge from the person)', 'GOTO (in front of the door)', 'PLACE CHARGE ON DOOR', 'GOTO (behind the barrier)']
# Plan Queue: [['SCAN', 'SCAN (the environment to populate scene_objects)'], ['GOTO', 'GOTO (to the person behind the barrier)'], ['RECEIVE OBJECT', 'RECEIVE OBJECT (the charge from the person)'], ['GOTO', 'GOTO (in front of the door)'], ['PLACE CHARGE ON DOOR', 'PLACE CHARGE ON DOOR'], ['GOTO', 'GOTO (behind the barrier)']]
